# %%
import json
import parser
import importlib
importlib.reload(parser)
try:
    articles
except:
    articles = []
    with open('../posts.json') as fp:
        for line in fp:
            articles.append(json.loads(line))

# %%
article = next(article for article in articles if article['url'] == '/news-perspective/2022/03/news-scan-mar-14-2022')
list(parser.parse_article(article, notebook_debugging=True))
# Out:
# '2021'          2021-03-14 00:00:00
# '14 days'       2022-02-28 00:00:00
# 'days 1'        None
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The study evaluated time from exposure to diagnosis among
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     107
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  close contacts from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# ...
